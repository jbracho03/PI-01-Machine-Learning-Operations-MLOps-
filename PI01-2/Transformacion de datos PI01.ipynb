# %% [markdown]
# ## PROYECTO INDIVIDUAL I

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Transformaciones: El analista de datos requiere estas, y solo estas, transformaciones para sus datos:

# %% [markdown]
# Generar campo id: Cada id se compondrá de la primera letra del nombre de la plataforma, seguido del show_id ya presente en los datasets (ejemplo para títulos de Amazon = as123)

# %%
amazon = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\MLOpsReviews\amazon_prime_titles.csv")
amazon['ID']='a'+ amazon.show_id

amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
disney = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\MLOpsReviews\disney_plus_titles.csv")
disney['ID']='d'+ disney.show_id
disney
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
hulu = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\MLOpsReviews\hulu_titles.csv")
hulu['ID']='h'+ hulu.show_id
hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
netflix = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\MLOpsReviews\netflix_titles.csv")
netflix['ID']='n'+ netflix.show_id
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Los valores nulos del campo rating deberán reemplazarse por el string “G” (corresponde al maturity rating: “general for all audiences”

# %%
amazon["rating"].fillna("G",inplace=True)
amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
disney["rating"].fillna("G",inplace=True)
disney
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
hulu["rating"].fillna("G",inplace=True)
hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
netflix["rating"].fillna("G",inplace=True)
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# De haber fechas, deberán tener el formato AAAA-mm-dd

# %%
amazon['date_added'] = pd.to_datetime(amazon['date_added'], errors = 'coerce')

# %%
amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
disney['date_added'] = pd.to_datetime(disney['date_added'], errors = 'coerce')
disney
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
hulu['date_added'] = pd.to_datetime(hulu['date_added'], errors = 'coerce')
hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country date_added  release_year rating   duration  \
# 0                NaN 2021-10-24          2021  TV-MA        NaN
# ...

# %%
netflix['date_added'] = pd.to_datetime(netflix['date_added'], errors = 'coerce')
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Los campos de texto deberán estar en minúsculas, sin excepciones

# %%
# Cambio los campos de texto, de mayusculas a minusculas.

amazon["type"] = amazon["type"].str.lower()
amazon["title"] = amazon["title"].str.lower()
amazon["director"] = amazon["director"].str.lower()
amazon["cast"] = amazon["cast"].str.lower()
amazon["country"] = amazon["country"].str.lower()
amazon["rating"] = amazon["rating"].str.lower()
#amazon["duration_type"] = amazon["duration_type"].str.lower()
amazon["listed_in"] = amazon["listed_in"].str.lower()
amazon["description"] = amazon["description"].str.lower()

# %%
disney["type"] = disney["type"].str.lower()
disney["title"] = disney["title"].str.lower()
disney["director"] = disney["director"].str.lower()
disney["cast"] = disney["cast"].str.lower()
disney["country"] = disney["country"].str.lower()
disney["rating"] = disney["rating"].str.lower()
#disney["duration_type"] = disney["duration_type"].str.lower()
disney["listed_in"] = disney["listed_in"].str.lower()
disney["description"] = disney["description"].str.lower()

# %%
hulu["type"] = hulu["type"].str.lower()
hulu["title"] = hulu["title"].str.lower()
hulu["director"] = hulu["director"].str.lower()
hulu["country"] = hulu["country"].str.lower()
hulu["rating"] = hulu["rating"].str.lower()
#hulu["duration_type"] = hulu["duration_type"].str.lower()
hulu["listed_in"] = hulu["listed_in"].str.lower()
hulu["description"] = hulu["description"].str.lower()

# %%
netflix["type"] = netflix["type"].str.lower()
netflix["title"] = netflix["title"].str.lower()
netflix["director"] = netflix["director"].str.lower()
netflix["cast"] = netflix["cast"].str.lower()
netflix["country"] = netflix["country"].str.lower()
netflix["rating"] = netflix["rating"].str.lower()
#netflix["duration_type"] = netflix["duration_type"].str.lower()
netflix["listed_in"] = netflix["listed_in"].str.lower()
netflix["description"] = netflix["description"].str.lower()

# %% [markdown]
# El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o season (temporadas)

# %%
amazon[['duration_int', 'duration_type']] = amazon['duration'].str.split(' ', n=-1, expand=True, regex=None)
amazon = amazon[amazon.columns[:10].tolist() + ['duration_int', 'duration_type'] + amazon.columns[10:-2].tolist()]

# %%
amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    movie      the grand seduction     don mckellar
# 1         s2    movie     take care good night     girish joshi
# 2         s3    movie     secrets of deception      josh webber
# 3         s4    movie       pink: staying true   sonia anderson
# 4         s5    movie            monster maker     giles foster
# ...      ...      ...                      ...              ...
# 9663   s9664    movie      pride of the bowery  joseph h. lewis
# 9664   s9665  tv show            planet patrol              NaN
# 9665   s9666    movie                  outpost     steve barker
# 9666   s9667  tv show  maradona: blessed dream              NaN
# 9667   s9668    movie              harry brown    daniel barber
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# ...

# %%
disney[['duration_int', 'duration_type']] = disney['duration'].str.split(' ', n=-1, expand=True, regex=None)
disney = disney[disney.columns[:10].tolist() + ['duration_int', 'duration_type'] + disney.columns[10:-2].tolist()]

# %%
disney
# Out:
#      show_id     type                                             title  \
# 0         s1    movie  duck the halls: a mickey mouse christmas special
# 1         s2    movie                            ernest saves christmas
# 2         s3    movie                      ice age: a mammoth christmas
# 3         s4    movie                        the queen family singalong
# 4         s5  tv show                             the beatles: get back
# ...      ...      ...                                               ...
# 1445   s1446    movie                          x-men origins: wolverine
# 1446   s1447    movie    night at the museum: battle of the smithsonian
# 1447   s1448    movie                                   eddie the eagle
# 1448   s1449    movie                              bend it like beckham
# 1449   s1450    movie             captain sparky vs. the flying saucers
#
#                                director  \
# 0     alonso ramirez ramos, dave wasson
# ...

# %%
hulu[['duration_int', 'duration_type']] = hulu['duration'].str.split(' ', n=-1, expand=True, regex=None)
hulu = hulu[hulu.columns[:10].tolist() + ['duration_int', 'duration_type'] + hulu.columns[10:-2].tolist()]

# %%
hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    movie  ricky velez: here's everything      NaN   NaN
# 1         s2    movie                    silent night      NaN   NaN
# 2         s3    movie                    the marksman      NaN   NaN
# 3         s4    movie                            gaia      NaN   NaN
# 4         s5    movie                        settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  tv show  star trek: the original series      NaN   NaN
# 3069   s3070  tv show              star trek: voyager      NaN   NaN
# 3070   s3071  tv show                       the fades      NaN   NaN
# 3071   s3072  tv show               the twilight zone      NaN   NaN
# 3072   s3073  tv show             tokyo magnitude 8.0      NaN   NaN
#
#              country date_added  release_year rating   duration duration_int  \
# ...

# %%
netflix[['duration_int', 'duration_type']] = netflix['duration'].str.split(' ', n=-1, expand=True, regex=None)
netflix = netflix[netflix.columns[:10].tolist() + ['duration_int', 'duration_type'] + netflix.columns[10:-2].tolist()]

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    movie   dick johnson is dead  kirsten johnson
# 1         s2  tv show          blood & water              NaN
# 2         s3  tv show              ganglands  julien leclercq
# 3         s4  tv show  jailbirds new orleans              NaN
# 4         s5  tv show           kota factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 zodiac    david fincher
# 8803   s8804  tv show            zombie dumb              NaN
# 8804   s8805    movie             zombieland  ruben fleischer
# 8805   s8806    movie                   zoom     peter hewitt
# 8806   s8807    movie                 zubaan      mozez singh
#
#                                                    cast        country  \
# 0                                                   NaN  united states
# 1     ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# ...

# %% [markdown]
# Se normaliza Seasons a season

# %%
amazon['duration_type'] = amazon['duration_type'].replace('Seasons','season')
amazon['duration_type'] = amazon['duration_type'].replace('Season','season')

# %%
disney['duration_type'] = disney['duration_type'].replace('Seasons','season')
disney['duration_type'] = disney['duration_type'].replace('Season','season')

# %%
hulu['duration_type'] = hulu['duration_type'].replace('Seasons','season')
hulu['duration_type'] = hulu['duration_type'].replace('Season','season')

# %%
netflix['duration_type'] = netflix['duration_type'].replace('Seasons','season')
netflix['duration_type'] = netflix['duration_type'].replace('Season','season')

# %% [markdown]
# Transformaciones: El analista de datos requiere estas, y solo estas, transformaciones para sus datos:
#
# Generar campo id: Cada id se compondrá de la primera letra del nombre de la plataforma, seguido del show_id ya presente en los datasets (ejemplo para títulos de Amazon = as123)
#
# Los valores nulos del campo rating deberán reemplazarse por el string “G” (corresponde al maturity rating: “general for all audiences”
#
# De haber fechas, deberán tener el formato AAAA-mm-dd
#
# Los campos de texto deberán estar en minúsculas, sin excepciones
#
# El campo duration debe convertirse en dos campos: duration_int y duration_type. El primero será un integer y el segundo un string indicando la unidad de medición de duración: min (minutos) o season (temporadas)

# %% [markdown]
# ## Amazon prime

# %%
amazon
# Out:
#      show_id     type                    title         director  \
# 0         s1    movie      the grand seduction     don mckellar
# 1         s2    movie     take care good night     girish joshi
# 2         s3    movie     secrets of deception      josh webber
# 3         s4    movie       pink: staying true   sonia anderson
# 4         s5    movie            monster maker     giles foster
# ...      ...      ...                      ...              ...
# 9663   s9664    movie      pride of the bowery  joseph h. lewis
# 9664   s9665  tv show            planet patrol              NaN
# 9665   s9666    movie                  outpost     steve barker
# 9666   s9667  tv show  maradona: blessed dream              NaN
# 9667   s9668    movie              harry brown    daniel barber
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# ...

# %% [markdown]
# ## DisneyPlus

# %%
disney
# Out:
#      show_id     type                                             title  \
# 0         s1    movie  duck the halls: a mickey mouse christmas special
# 1         s2    movie                            ernest saves christmas
# 2         s3    movie                      ice age: a mammoth christmas
# 3         s4    movie                        the queen family singalong
# 4         s5  tv show                             the beatles: get back
# ...      ...      ...                                               ...
# 1445   s1446    movie                          x-men origins: wolverine
# 1446   s1447    movie    night at the museum: battle of the smithsonian
# 1447   s1448    movie                                   eddie the eagle
# 1448   s1449    movie                              bend it like beckham
# 1449   s1450    movie             captain sparky vs. the flying saucers
#
#                                director  \
# 0     alonso ramirez ramos, dave wasson
# ...

# %% [markdown]
# ## Hulu

# %%
hulu
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    movie  ricky velez: here's everything      NaN   NaN
# 1         s2    movie                    silent night      NaN   NaN
# 2         s3    movie                    the marksman      NaN   NaN
# 3         s4    movie                            gaia      NaN   NaN
# 4         s5    movie                        settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  tv show  star trek: the original series      NaN   NaN
# 3069   s3070  tv show              star trek: voyager      NaN   NaN
# 3070   s3071  tv show                       the fades      NaN   NaN
# 3071   s3072  tv show               the twilight zone      NaN   NaN
# 3072   s3073  tv show             tokyo magnitude 8.0      NaN   NaN
#
#              country date_added  release_year rating   duration duration_int  \
# ...

# %% [markdown]
# ## Netflix

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    movie   dick johnson is dead  kirsten johnson
# 1         s2  tv show          blood & water              NaN
# 2         s3  tv show              ganglands  julien leclercq
# 3         s4  tv show  jailbirds new orleans              NaN
# 4         s5  tv show           kota factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    movie                 zodiac    david fincher
# 8803   s8804  tv show            zombie dumb              NaN
# 8804   s8805    movie             zombieland  ruben fleischer
# 8805   s8806    movie                   zoom     peter hewitt
# 8806   s8807    movie                 zubaan      mozez singh
#
#                                                    cast        country  \
# 0                                                   NaN  united states
# 1     ama qamata, khosi ngema, gail mabalane, thaban...   south africa
# ...

# %% [markdown]
# CONCATENAR DATAFRAMES

# %%
datos_PI_1 = pd.concat([amazon, disney, hulu, netflix], axis = 0)

# %%
datos_PI_1
# Out:
#      show_id     type                 title         director  \
# 0         s1    movie   the grand seduction     don mckellar
# 1         s2    movie  take care good night     girish joshi
# 2         s3    movie  secrets of deception      josh webber
# 3         s4    movie    pink: staying true   sonia anderson
# 4         s5    movie         monster maker     giles foster
# ...      ...      ...                   ...              ...
# 8802   s8803    movie                zodiac    david fincher
# 8803   s8804  tv show           zombie dumb              NaN
# 8804   s8805    movie            zombieland  ruben fleischer
# 8805   s8806    movie                  zoom     peter hewitt
# 8806   s8807    movie                zubaan      mozez singh
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# ...

# %%
datos_PI_1 = datos_PI_1.rename(columns={'ID': 'id'})

# %%
datos_PI_1.reset_index().to_csv('DatosA.csv', header = True, index = False)

# %% [markdown]
# Ratings

# %%
ratings1 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\1.csv")
ratings1
# Out:
#          userId  rating   timestamp movieId
# 0             1     1.0  1425941529   as680
# 1             1     4.5  1425942435  ns2186
# 2             1     5.0  1425941523  hs2381
# 3             1     5.0  1425941546  ns3663
# 4             1     5.0  1425941556  as9500
# ...         ...     ...         ...     ...
# 1499995   15424     4.0  1370209959  as8698
# 1499996   15424     3.5  1369586045  as3663
# 1499997   15424     3.0  1372541792  as1325
# 1499998   15424     3.5  1372541811  ns4446
# 1499999   15424     3.5  1369606242  hs2569
#
# [1500000 rows x 4 columns]

# %%
ratings2 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\2.csv")
ratings2
# Out:
#          userId  rating   timestamp movieId
# 0         15424     3.0  1369585147  ns3012
# 1         15424     2.5  1369586851  ns3195
# 2         15424     3.0  1369585112   ns357
# 3         15424     2.5  1372541498  as7069
# 4         15424     3.0  1369586846  as6943
# ...         ...     ...         ...     ...
# 1499995   31331     4.0   867662780  as2992
# 1499996   31331     5.0   867662780  as8070
# 1499997   31331     4.0   867663188  as7838
# 1499998   31332     4.0   974205034  ns5462
# 1499999   31332     4.0   974205170  hs2852
#
# [1500000 rows x 4 columns]

# %%
ratings3 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\3.csv")
ratings3
# Out:
#          userId  rating   timestamp movieId
# 0         31332     4.0   974205261  as2251
# 1         31332     3.0   974205170  as7226
# 2         31332     3.0   974205034  as6479
# 3         31332     3.0   974205261  ns2422
# 4         31332     4.0   974205034  as4041
# ...         ...     ...         ...     ...
# 1499995   46200     4.0   994446596  as1415
# 1499996   46200     3.0   996245672   as927
# 1499997   46200     4.0   994446583  as8130
# 1499998   46200     4.0   996245646  ns5545
# 1499999   46200     4.0  1004466542  ns3187
#
# [1500000 rows x 4 columns]

# %%
ratings4 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\4.csv")
ratings4
# Out:
#          userId  rating   timestamp movieId
# 0         46200     5.0  1015603683  as3203
# 1         46200     1.0  1012323069  as5959
# 2         46200     3.0   996245609  as4430
# 3         46200     4.0   996245595  as6604
# 4         46200     3.0   996245595   ds311
# ...         ...     ...         ...     ...
# 1499995   61768     3.5  1438075483  hs1021
# 1499996   61768     3.0  1438075487   hs885
# 1499997   61768     4.0  1435694368  as4321
# 1499998   61768     4.0  1438075493  hs2422
# 1499999   61768     3.5  1438075491  as6170
#
# [1500000 rows x 4 columns]

# %%
ratings5 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\5.csv")
ratings5
# Out:
#          userId  rating   timestamp movieId
# 0         61768     4.0  1438075492  as5376
# 1         61768     3.0  1435693148  as7172
# 2         61768     3.0  1438075482  ns4557
# 3         61768     3.0  1438075496  ns7804
# 4         61768     3.5  1438075486  as3030
# ...         ...     ...         ...     ...
# 1499995   77403     4.0   852669256  as2081
# 1499996   77403     3.0   852669256  ns4047
# 1499997   77403     3.0   852669255   ns787
# 1499998   77403     3.0   852669333   hs541
# 1499999   77403     5.0   852669333  ns7174
#
# [1500000 rows x 4 columns]

# %%
ratings6 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\6.csv")
ratings6
# Out:
#          userId  rating   timestamp movieId
# 0        249182     3.5  1460518555   ds327
# 1        249182     4.0  1461878500  ns2124
# 2        249182     3.0  1460182087  as8841
# 3        249182     4.5  1460183214  hs2318
# 4        249182     2.5  1460184332  as5743
# ...         ...     ...         ...     ...
# 1499995  265409     5.0   891417264  as4345
# 1499996  265409     5.0   891417377  ns5982
# 1499997  265409     4.0   891417191  ns4622
# 1499998  265409     5.0   891417377  as3351
# 1499999  265409     4.0   891417573  ns6806
#
# [1500000 rows x 4 columns]

# %%
ratings7 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\7.csv")
ratings7
# Out:
#         userId  rating   timestamp movieId
# 0       265409     5.0   891417042   ds781
# 1       265409     5.0   891417042  as9331
# 2       265409     4.0   891417435   hs384
# 3       265409     3.0   891417191   hs398
# 4       265409     5.0   891417224  as8434
# ...        ...     ...         ...     ...
# 524284  270896     5.0  1257031564   hs447
# 524285  270896     5.0  1257032032  ns8706
# 524286  270896     4.5  1257031764  ns4476
# 524287  270896     4.5  1257033990  ns6149
# 524288  270896     2.0  1257031858  as6079
#
# [524289 rows x 4 columns]

# %%
ratings8 = pd.read_csv(r"C:\Users\Roman Samuel Bracho\Desktop\HENRY\ratings\8.csv")
ratings8
# Out:
#          userId  rating   timestamp movieId
# 0        108422     4.5  1350689762  as1399
# 1        108422     4.0  1350341401  as6724
# 2        108422     5.0  1350689691   ns512
# 3        108422     4.5  1350341088  ns7444
# 4        108422     4.5  1350689619  as2230
# ...         ...     ...         ...     ...
# 1499995  124380     4.5  1196786159  ns5272
# 1499996  124380     2.5  1196786030  ns5492
# 1499997  124380     3.5  1196785679   hs305
# 1499998  124380     4.5  1196787089  ns7881
# 1499999  124380     1.5  1196785847   as883
#
# [1500000 rows x 4 columns]

# %%
ratings = pd.concat([ratings1, ratings2, ratings2, ratings3, ratings4, ratings5, ratings6, ratings7, ratings8], axis = 0)

# %%
ratings
# Out:
#          userId  rating   timestamp movieId
# 0             1     1.0  1425941529   as680
# 1             1     4.5  1425942435  ns2186
# 2             1     5.0  1425941523  hs2381
# 3             1     5.0  1425941546  ns3663
# 4             1     5.0  1425941556  as9500
# ...         ...     ...         ...     ...
# 1499995  124380     4.5  1196786159  ns5272
# 1499996  124380     2.5  1196786030  ns5492
# 1499997  124380     3.5  1196785679   hs305
# 1499998  124380     4.5  1196787089  ns7881
# 1499999  124380     1.5  1196785847   as883
#
# [12524289 rows x 4 columns]

# %%
ratings = ratings.rename(columns={'rating': 'score'})

# %%
ratings
# Out:
#          userId  score   timestamp movieId
# 0             1    1.0  1425941529   as680
# 1             1    4.5  1425942435  ns2186
# 2             1    5.0  1425941523  hs2381
# 3             1    5.0  1425941546  ns3663
# 4             1    5.0  1425941556  as9500
# ...         ...    ...         ...     ...
# 1499995  124380    4.5  1196786159  ns5272
# 1499996  124380    2.5  1196786030  ns5492
# 1499997  124380    3.5  1196785679   hs305
# 1499998  124380    4.5  1196787089  ns7881
# 1499999  124380    1.5  1196785847   as883
#
# [12524289 rows x 4 columns]

# %%
import numpy as np

mask0 = ratings['movieId'].str.startswith('ama')
ratings['movieId'] = np.where(mask0, ratings['movieId'].str.replace('ama', 'as'), ratings['movieId'])

# %%
mask = ratings['movieId'].str.startswith('net')
ratings['movieId'] = np.where(mask, ratings['movieId'].str.replace('net', 'n'), ratings['movieId'])

# %%
mask1 = ratings['movieId'].str.startswith('hul')
ratings['movieId'] = np.where(mask1, ratings['movieId'].str.replace('hul', 'h'), ratings['movieId'])

# %%
mask2 = ratings['movieId'].str.startswith('dis')
ratings['movieId'] = np.where(mask2, ratings['movieId'].str.replace('dis', 'd'), ratings['movieId'])

# %%
ratings
# Out:
#          userId  score   timestamp movieId
# 0             1    1.0  1425941529   as680
# 1             1    4.5  1425942435  ns2186
# 2             1    5.0  1425941523  hs2381
# 3             1    5.0  1425941546  ns3663
# 4             1    5.0  1425941556  as9500
# ...         ...    ...         ...     ...
# 1499995  124380    4.5  1196786159  ns5272
# 1499996  124380    2.5  1196786030  ns5492
# 1499997  124380    3.5  1196785679   hs305
# 1499998  124380    4.5  1196787089  ns7881
# 1499999  124380    1.5  1196785847   as883
#
# [12524289 rows x 4 columns]

# %%
ratings['avg_rating'] = ratings.groupby(['userId', 'movieId'])['score'].mean().reset_index(drop=True)

# %%
ratings = ratings.drop_duplicates(subset=['movieId'])

# %%
ratings = ratings.rename(columns={'avg_rating': 'ScoreMedia'})

# %%
ratings = ratings.drop(['timestamp'], axis=1)

# %%
ratings
# Out:
#         userId  score movieId  ScoreMedia
# 0            1    1.0   as680         5.0
# 1            1    4.5  ns2186         4.0
# 2            1    5.0  hs2381         5.0
# 3            1    5.0  ns3663         4.0
# 4            1    5.0  as9500         5.0
# ...        ...    ...     ...         ...
# 182025    1888    3.5  ns4069         2.5
# 195443    2030    4.5   ds619         3.0
# 198037    2062    4.0  ns7976         4.0
# 240502    2531    5.0  ns1837         3.0
# 281673    2975    4.0   ns720         4.0
#
# [22998 rows x 4 columns]

# %%
merged_df = datos_PI_1.merge(ratings, left_on='id', right_on='movieId', how='inner')

# %%
ratings = merged_df.drop(columns=['show_id', 'type', 'director','cast', 'country', 'date_added',	'release_year',	'rating', 'duration', 'duration_int', 'duration_type', 'description', 'id', 'ScoreMedia'])

# %%
ratings = merged_df.drop(['ScoreMedia'], axis=1)

# %%
ratings
# Out:
#                       title                                       listed_in  \
# 0       the grand seduction                                   comedy, drama
# 1      take care good night                            drama, international
# 2      secrets of deception                         action, drama, suspense
# 3        pink: staying true                                     documentary
# 4             monster maker                                  drama, fantasy
# ...                     ...                                             ...
# 22993                zodiac                  cult movies, dramas, thrillers
# 22994           zombie dumb          kids' tv, korean tv shows, tv comedies
# 22995            zombieland                         comedies, horror movies
# 22996                  zoom              children & family movies, comedies
# 22997                zubaan  dramas, international movies, music & musicals
#
#        userId  score movieId
# ...

# %%
ratings.reset_index().to_csv('Datos_ratings.csv', header = True, index = False)

# %%
##merged_df.reset_index().to_csv('Datos_PI.csv', header = True, index = False)
